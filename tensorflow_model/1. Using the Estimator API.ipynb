# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import argparse, os, sys

from __future__ import division, print_function, absolute_import
from util_functions import process_files, random_mini_batches

FLAGS = None

# load the data
x_train, y_train, f_train = process_files(
                                    dataset='training', 
                                    features=['Mel', 'Mel_deltas'], 
                                    shape='flat')

x_test, y_test, f_test = process_files(
                                    dataset='test', 
                                    features=['Mel', 'Mel_deltas'], 
                                    shape='flat')

x_train = x_train.astype(np.float32)
x_test = x_test.astype(np.float32)

tf.logging.set_verbosity(tf.logging.INFO)

# %%
#Seeding
seed = 3

# input image dimensions
input_d = x_train.shape[1] #Depth
input_h = x_train.shape[2] #Height
input_w = x_train.shape[3] #Width

num_classes = 2

# %%
def sound_net(features, labels, mode):

    predictions = None
    loss = None
    train_op = None
    eval_metric_ops = None
    
    # Input Layer
    x = tf.reshape(features["x"], [-1, input_h, input_w, input_d])

    # Convolutional Layer #1
    # input shape [batch_size, input_h, input_w, input_d]
    # output shape [batch_size, input_h, input_w, 80]        
    conv1 = tf.layers.conv2d(inputs=x, filters=80, kernel_size=[57, 6], padding="same", 
                             activation=tf.nn.relu, name='conv1')

    # Pooling Layer #1
    # First max pooling layer with a 2x2 filter and stride of 2
    # input shape [batch_size, input_h, input_w, 80]
    # output shape [batch_size, input_h/2, input_w/2, 80]
    pool1 = tf.layers.max_pooling2d(inputs=conv1, pool_size=[2, 2], padding="same", strides=2)
    pool1 = tf.layers.dropout(inputs=pool1, rate=FLAGS.dropout, training=mode == tf.estimator.ModeKeys.TRAIN, name='pool1')

    # Convolutional Layer #2
    # input shape [batch_size, input_h/2, input_w/2, 80]
    # output shape [batch_size, input_h/2, input_w/2, 80]
    conv2 = tf.layers.conv2d(inputs=pool1, filters=80, kernel_size=[1, 3], 
                             padding="same", activation=tf.nn.relu, name='conv2')
    
    # Pooling Layer #2
    # Input Tensor Shape: [batch_size, input_h/2, input_w/2, 80]
    # Output Tensor Shape: [batch_size, input_h/16 input_w/14, 80]    
    pool2 = tf.layers.max_pooling2d(inputs=conv2, pool_size=[8, 7], padding="same", 
                                    strides=[8, 7], name='pool1')

    # Fully connected layer #1
    # Reshape conv2 output to fit fully connected layer input
    pool2_flat = tf.reshape(pool2, [-1, int(input_h/16)*int(input_w/14)*80])    
    dense1 = tf.layers.dense(inputs=pool2_flat, units=1024, activation=tf.nn.relu)
    dense1 = tf.layers.dropout(inputs=dense1, rate=FLAGS.dropout, training=mode == tf.estimator.ModeKeys.TRAIN)

    # Fully connected layer #2
    dense2 = tf.layers.dense(inputs=dense1, units=1024, activation=tf.nn.relu)
    dense2 = tf.layers.dropout(inputs=dense2, rate=FLAGS.dropout, training=mode == tf.estimator.ModeKeys.TRAIN)    
    
    # Logits layer
    logits = tf.layers.dense(inputs=dense2, units=num_classes)

    predictions = {
      "classes": tf.argmax(input=logits, axis=1),
      "probabilities": tf.nn.softmax(logits, name="softmax_tensor")
    }
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)

    # Calculate Loss (for both TRAIN and EVAL modes)
    loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits, labels=labels), name='loss_tensor')   
    correct_prediction = tf.equal(tf.argmax(logits, 1), labels) 
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32), name='accuracy_tensor')
    tf.summary.scalar('accuracy', accuracy)
        
    eval_metric_ops = {
      "accuracy": tf.metrics.accuracy(labels=labels, predictions=predictions["classes"])}
    
    # Configure the Training Op (for TRAIN mode)
    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.train.AdamOptimizer(learning_rate=FLAGS.learning_rate)
        train_op = optimizer.minimize(
            loss=loss,
            global_step=tf.train.get_global_step())
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op, eval_metric_ops=eval_metric_ops)

  # Add evaluation metrics (for EVAL mode)
    eval_metric_ops = {
      "accuracy": tf.metrics.accuracy(labels=labels, predictions=predictions["classes"])}
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %%
def main(_):

    # Create the Estimator or warm-start the last one
    sound_classifier = tf.estimator.Estimator(
      model_fn=sound_net, model_dir=FLAGS.model_folder)
    
    # Set up logging for predictions
    tensors_to_log = {"loss": "loss_tensor", "accuracy": "accuracy_tensor"}
    logging_hook = tf.train.LoggingTensorHook(tensors_to_log, every_n_iter=100)

    # Train the model
    train_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": x_train},
      y=y_train,
      batch_size=32,
      num_epochs=None,
      shuffle=True)
    
    sound_classifier.train(
      input_fn=train_input_fn,
      steps=FLAGS.max_steps,
      hooks=[logging_hook])

    # Evaluate the model and print results
    eval_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={"x": x_test},
      y=y_test,
      num_epochs=1,
      shuffle=False)
    eval_results = sound_classifier.evaluate(input_fn=eval_input_fn)
    print(eval_results)

# %%
if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument('--max_steps', type=int, default=10000,
                      help='Number of steps to run trainer.')
    parser.add_argument('--learning_rate', type=float, default=0.0001,
                      help='Initial learning rate')
    parser.add_argument('--dropout', type=float, default=0.4,
                      help='Keep probability for training dropout.')
    parser.add_argument('--model_folder', type=str, default="saved_models/estimator_api",
                      help='Folder where the model will be saved.')
    
    FLAGS, unparsed = parser.parse_known_args()    
    tf.app.run(main=main, argv=[sys.argv[0]] + unparsed)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': 'saved_models/estimator_api', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f85244c0cc0>, '_task_type': 'worker', '_task_id': 0, '_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into saved_models/estimator_api/model.ckpt.
# INFO:tensorflow:loss = 5.1302285, accuracy = 0.5
# INFO:tensorflow:loss = 5.1302285, step = 1
# INFO:tensorflow:global_step/sec: 9.40131
# INFO:tensorflow:loss = 6.7936606, accuracy = 0.6875 (10.638 sec)
# INFO:tensorflow:loss = 6.7936606, step = 101 (10.638 sec)
# INFO:tensorflow:global_step/sec: 9.41488
# INFO:tensorflow:loss = 1.4144281, accuracy = 0.78125 (10.622 sec)
# INFO:tensorflow:loss = 1.4144281, step = 201 (10.622 sec)
# INFO:tensorflow:global_step/sec: 9.41662
# INFO:tensorflow:loss = 0.43498635, accuracy = 0.8125 (10.619 sec)
# INFO:tensorflow:loss = 0.43498635, step = 301 (10.619 sec)
# INFO:tensorflow:global_step/sec: 9.42491
# INFO:tensorflow:loss = 0.45704117, accuracy = 0.875 (10.610 sec)
# INFO:tensorflow:loss = 0.45704117, step = 401 (10.610 sec)
# INFO:tensorflow:global_step/sec: 9.42618
# INFO:tensorflow:loss = 0.77895033, accuracy = 0.8125 (10.611 sec)
# INFO:tensorflow:loss = 0.77895033, step = 501 (10.611 sec)
# INFO:tensorflow:global_step/sec: 9.42508
# INFO:tensorflow:loss = 0.9865527, accuracy = 0.8125 (10.608 sec)
# INFO:tensorflow:loss = 0.9865527, step = 601 (10.608 sec)
# INFO:tensorflow:global_step/sec: 9.42427
# INFO:tensorflow:loss = 0.25912756, accuracy = 0.90625 (10.611 sec)
# INFO:tensorflow:loss = 0.25912756, step = 701 (10.611 sec)
# INFO:tensorflow:global_step/sec: 9.42525
# INFO:tensorflow:loss = 0.4662663, accuracy = 0.78125 (10.610 sec)
# INFO:tensorflow:loss = 0.4662663, step = 801 (10.610 sec)
# INFO:tensorflow:global_step/sec: 9.4287
# INFO:tensorflow:loss = 0.55131817, accuracy = 0.84375 (10.606 sec)
# INFO:tensorflow:loss = 0.55131817, step = 901 (10.606 sec)
# INFO:tensorflow:global_step/sec: 9.42341
# INFO:tensorflow:loss = 1.1983223, accuracy = 0.6875 (10.612 sec)
# INFO:tensorflow:loss = 1.1983223, step = 1001 (10.612 sec)
# INFO:tensorflow:global_step/sec: 9.41984
# INFO:tensorflow:loss = 0.7895143, accuracy = 0.875 (10.616 sec)
# INFO:tensorflow:loss = 0.7895143, step = 1101 (10.616 sec)
# INFO:tensorflow:global_step/sec: 9.42732
# INFO:tensorflow:loss = 0.446173, accuracy = 0.78125 (10.608 sec)
# INFO:tensorflow:loss = 0.446173, step = 1201 (10.608 sec)
# INFO:tensorflow:global_step/sec: 9.42699
# INFO:tensorflow:loss = 0.21615791, accuracy = 0.9375 (10.608 sec)
# INFO:tensorflow:loss = 0.21615791, step = 1301 (10.608 sec)
# INFO:tensorflow:global_step/sec: 9.42874
# INFO:tensorflow:loss = 0.40418565, accuracy = 0.8125 (10.606 sec)
# INFO:tensorflow:loss = 0.40418565, step = 1401 (10.606 sec)
# INFO:tensorflow:global_step/sec: 9.42729
# INFO:tensorflow:loss = 0.44105923, accuracy = 0.84375 (10.607 sec)
# INFO:tensorflow:loss = 0.44105923, step = 1501 (10.607 sec)
# INFO:tensorflow:global_step/sec: 9.42887
# INFO:tensorflow:loss = 0.4385255, accuracy = 0.8125 (10.606 sec)
# INFO:tensorflow:loss = 0.4385255, step = 1601 (10.606 sec)
# INFO:tensorflow:global_step/sec: 9.42545
# INFO:tensorflow:loss = 0.18424317, accuracy = 0.9375 (10.610 sec)
# INFO:tensorflow:loss = 0.18424317, step = 1701 (10.610 sec)
# INFO:tensorflow:global_step/sec: 9.42811
# INFO:tensorflow:loss = 0.18613368, accuracy = 0.9375 (10.606 sec)
# INFO:tensorflow:loss = 0.18613368, step = 1801 (10.606 sec)
# INFO:tensorflow:global_step/sec: 9.449
# INFO:tensorflow:loss = 0.26389748, accuracy = 0.875 (10.583 sec)
# INFO:tensorflow:loss = 0.26389748, step = 1901 (10.583 sec)
# INFO:tensorflow:global_step/sec: 9.45221
# INFO:tensorflow:loss = 0.7298669, accuracy = 0.8125 (10.580 sec)
# INFO:tensorflow:loss = 0.7298669, step = 2001 (10.580 sec)
# INFO:tensorflow:global_step/sec: 9.45766
# INFO:tensorflow:loss = 0.20336516, accuracy = 0.90625 (10.574 sec)
# INFO:tensorflow:loss = 0.20336516, step = 2101 (10.573 sec)
# INFO:tensorflow:global_step/sec: 9.42816
# INFO:tensorflow:loss = 0.1772593, accuracy = 0.90625 (10.607 sec)
# INFO:tensorflow:loss = 0.1772593, step = 2201 (10.607 sec)
# INFO:tensorflow:global_step/sec: 9.44945
# INFO:tensorflow:loss = 0.1824492, accuracy = 0.875 (10.582 sec)
# INFO:tensorflow:loss = 0.1824492, step = 2301 (10.582 sec)
# INFO:tensorflow:global_step/sec: 9.46042
# INFO:tensorflow:loss = 0.355031, accuracy = 0.78125 (10.570 sec)
# INFO:tensorflow:loss = 0.355031, step = 2401 (10.571 sec)
# INFO:tensorflow:global_step/sec: 9.46162
# INFO:tensorflow:loss = 0.51384175, accuracy = 0.9375 (10.569 sec)
# INFO:tensorflow:loss = 0.51384175, step = 2501 (10.569 sec)
# INFO:tensorflow:global_step/sec: 9.46042
# INFO:tensorflow:loss = 0.26003927, accuracy = 0.9375 (10.570 sec)
# INFO:tensorflow:loss = 0.26003927, step = 2601 (10.570 sec)
# INFO:tensorflow:global_step/sec: 9.45273
# INFO:tensorflow:loss = 0.26379472, accuracy = 0.875 (10.579 sec)
# INFO:tensorflow:loss = 0.26379472, step = 2701 (10.579 sec)
# INFO:tensorflow:global_step/sec: 9.43866
# INFO:tensorflow:loss = 0.23647301, accuracy = 0.9375 (10.595 sec)
# INFO:tensorflow:loss = 0.23647301, step = 2801 (10.595 sec)
# INFO:tensorflow:global_step/sec: 9.43908
# INFO:tensorflow:loss = 0.31023785, accuracy = 0.875 (10.594 sec)
# INFO:tensorflow:loss = 0.31023785, step = 2901 (10.594 sec)
# INFO:tensorflow:global_step/sec: 9.45516
# INFO:tensorflow:loss = 0.25072318, accuracy = 0.9375 (10.576 sec)
# INFO:tensorflow:loss = 0.25072318, step = 3001 (10.576 sec)
# INFO:tensorflow:global_step/sec: 9.4578
# INFO:tensorflow:loss = 0.2705674, accuracy = 0.84375 (10.573 sec)
# INFO:tensorflow:loss = 0.2705674, step = 3101 (10.573 sec)
# INFO:tensorflow:global_step/sec: 9.46154
# INFO:tensorflow:loss = 0.16166946, accuracy = 0.96875 (10.569 sec)
# INFO:tensorflow:loss = 0.16166946, step = 3201 (10.570 sec)
# INFO:tensorflow:global_step/sec: 9.46029
# INFO:tensorflow:loss = 0.15546346, accuracy = 0.96875 (10.570 sec)
# INFO:tensorflow:loss = 0.15546346, step = 3301 (10.570 sec)
# INFO:tensorflow:global_step/sec: 9.45859
# INFO:tensorflow:loss = 0.17426112, accuracy = 0.90625 (10.572 sec)
# INFO:tensorflow:loss = 0.17426112, step = 3401 (10.572 sec)
# INFO:tensorflow:global_step/sec: 9.45711
# INFO:tensorflow:loss = 0.11846872, accuracy = 0.96875 (10.574 sec)
# INFO:tensorflow:loss = 0.11846872, step = 3501 (10.574 sec)
# INFO:tensorflow:global_step/sec: 9.45936
# INFO:tensorflow:loss = 0.22619581, accuracy = 0.9375 (10.571 sec)
# INFO:tensorflow:loss = 0.22619581, step = 3601 (10.572 sec)
# INFO:tensorflow:global_step/sec: 9.45808
# INFO:tensorflow:loss = 0.22175516, accuracy = 0.875 (10.573 sec)
# INFO:tensorflow:loss = 0.22175516, step = 3701 (10.573 sec)
# INFO:tensorflow:global_step/sec: 9.46034
# INFO:tensorflow:loss = 0.099054396, accuracy = 0.96875 (10.570 sec)
# INFO:tensorflow:loss = 0.099054396, step = 3801 (10.570 sec)
# INFO:tensorflow:global_step/sec: 9.45943
# INFO:tensorflow:loss = 0.16314697, accuracy = 0.96875 (10.572 sec)
# INFO:tensorflow:loss = 0.16314697, step = 3901 (10.572 sec)
# INFO:tensorflow:global_step/sec: 9.45689
# INFO:tensorflow:loss = 0.14229025, accuracy = 0.9375 (10.576 sec)
# INFO:tensorflow:loss = 0.14229025, step = 4001 (10.576 sec)
# INFO:tensorflow:global_step/sec: 9.44319
# INFO:tensorflow:loss = 0.21103537, accuracy = 0.9375 (10.588 sec)
# INFO:tensorflow:loss = 0.21103537, step = 4101 (10.588 sec)
# INFO:tensorflow:global_step/sec: 9.4354
# INFO:tensorflow:loss = 0.12449066, accuracy = 0.9375 (10.598 sec)
# INFO:tensorflow:loss = 0.12449066, step = 4201 (10.598 sec)
# INFO:tensorflow:global_step/sec: 9.43092
# INFO:tensorflow:loss = 0.10812583, accuracy = 0.96875 (10.603 sec)
# INFO:tensorflow:loss = 0.10812583, step = 4301 (10.604 sec)
# INFO:tensorflow:global_step/sec: 9.43745
# INFO:tensorflow:loss = 0.12580656, accuracy = 0.9375 (10.596 sec)
# INFO:tensorflow:loss = 0.12580656, step = 4401 (10.597 sec)
# INFO:tensorflow:global_step/sec: 9.43541
# INFO:tensorflow:loss = 0.2636202, accuracy = 0.90625 (10.598 sec)
# INFO:tensorflow:loss = 0.2636202, step = 4501 (10.598 sec)
# INFO:tensorflow:global_step/sec: 9.43987
# INFO:tensorflow:loss = 0.20664205, accuracy = 0.9375 (10.594 sec)
# INFO:tensorflow:loss = 0.20664205, step = 4601 (10.594 sec)
# INFO:tensorflow:global_step/sec: 9.43846
# INFO:tensorflow:loss = 0.04210343, accuracy = 1.0 (10.594 sec)
# INFO:tensorflow:loss = 0.04210343, step = 4701 (10.594 sec)
# INFO:tensorflow:global_step/sec: 9.44037
# INFO:tensorflow:loss = 0.05871944, accuracy = 1.0 (10.593 sec)
# INFO:tensorflow:loss = 0.05871944, step = 4801 (10.593 sec)
# INFO:tensorflow:global_step/sec: 9.43934
# INFO:tensorflow:loss = 0.22414534, accuracy = 0.9375 (10.594 sec)
# INFO:tensorflow:loss = 0.22414534, step = 4901 (10.594 sec)
# INFO:tensorflow:global_step/sec: 9.4344
# INFO:tensorflow:loss = 0.25695798, accuracy = 0.9375 (10.600 sec)
# INFO:tensorflow:loss = 0.25695798, step = 5001 (10.600 sec)
# INFO:tensorflow:global_step/sec: 9.42806
# INFO:tensorflow:loss = 0.18282278, accuracy = 0.9375 (10.607 sec)
# INFO:tensorflow:loss = 0.18282278, step = 5101 (10.607 sec)
# INFO:tensorflow:global_step/sec: 9.43483
# INFO:tensorflow:loss = 0.15171762, accuracy = 0.96875 (10.599 sec)
# INFO:tensorflow:loss = 0.15171762, step = 5201 (10.599 sec)
# INFO:tensorflow:global_step/sec: 9.43665
# INFO:tensorflow:loss = 0.020018362, accuracy = 1.0 (10.597 sec)
# INFO:tensorflow:loss = 0.020018362, step = 5301 (10.597 sec)
# INFO:tensorflow:global_step/sec: 9.43512
# INFO:tensorflow:loss = 0.07996175, accuracy = 1.0 (10.599 sec)
# INFO:tensorflow:loss = 0.07996175, step = 5401 (10.599 sec)
# INFO:tensorflow:global_step/sec: 9.43649
# INFO:tensorflow:loss = 0.22779633, accuracy = 0.90625 (10.598 sec)
# INFO:tensorflow:loss = 0.22779633, step = 5501 (10.598 sec)
# INFO:tensorflow:global_step/sec: 9.43077
# INFO:tensorflow:loss = 0.06067323, accuracy = 1.0 (10.603 sec)
# INFO:tensorflow:loss = 0.06067323, step = 5601 (10.603 sec)
# INFO:tensorflow:Saving checkpoints for 5664 into saved_models/estimator_api/model.ckpt.
# INFO:tensorflow:global_step/sec: 9.32938
# INFO:tensorflow:loss = 0.06108095, accuracy = 1.0 (10.719 sec)
# INFO:tensorflow:loss = 0.06108095, step = 5701 (10.719 sec)
# INFO:tensorflow:global_step/sec: 9.43283
# INFO:tensorflow:loss = 0.11974364, accuracy = 0.96875 (10.601 sec)
# INFO:tensorflow:loss = 0.11974364, step = 5801 (10.601 sec)
# INFO:tensorflow:global_step/sec: 9.43933
# INFO:tensorflow:loss = 0.10409698, accuracy = 0.96875 (10.594 sec)
# INFO:tensorflow:loss = 0.10409698, step = 5901 (10.594 sec)
# INFO:tensorflow:global_step/sec: 9.42733
# INFO:tensorflow:loss = 0.060911536, accuracy = 1.0 (10.607 sec)
# INFO:tensorflow:loss = 0.060911536, step = 6001 (10.607 sec)
# INFO:tensorflow:global_step/sec: 9.44601
# INFO:tensorflow:loss = 0.23416272, accuracy = 0.875 (10.586 sec)
# INFO:tensorflow:loss = 0.23416272, step = 6101 (10.586 sec)
# INFO:tensorflow:global_step/sec: 9.4184
# INFO:tensorflow:loss = 0.13031256, accuracy = 0.9375 (10.618 sec)
# INFO:tensorflow:loss = 0.13031256, step = 6201 (10.618 sec)
# INFO:tensorflow:global_step/sec: 9.43078
# INFO:tensorflow:loss = 0.42149282, accuracy = 0.875 (10.604 sec)
# INFO:tensorflow:loss = 0.42149282, step = 6301 (10.604 sec)
# INFO:tensorflow:global_step/sec: 9.43148
# INFO:tensorflow:loss = 0.17832215, accuracy = 0.9375 (10.603 sec)
# INFO:tensorflow:loss = 0.17832215, step = 6401 (10.603 sec)
# INFO:tensorflow:global_step/sec: 9.43208
# INFO:tensorflow:loss = 0.16690852, accuracy = 0.875 (10.602 sec)
# INFO:tensorflow:loss = 0.16690852, step = 6501 (10.602 sec)
# INFO:tensorflow:global_step/sec: 9.43027
# INFO:tensorflow:loss = 0.1429683, accuracy = 0.9375 (10.604 sec)
# INFO:tensorflow:loss = 0.1429683, step = 6601 (10.604 sec)
# INFO:tensorflow:global_step/sec: 9.42852
# INFO:tensorflow:loss = 0.06548606, accuracy = 0.96875 (10.606 sec)
# INFO:tensorflow:loss = 0.06548606, step = 6701 (10.606 sec)
# INFO:tensorflow:global_step/sec: 9.42866
# INFO:tensorflow:loss = 0.3445958, accuracy = 0.9375 (10.607 sec)
# INFO:tensorflow:loss = 0.3445958, step = 6801 (10.607 sec)
# INFO:tensorflow:global_step/sec: 9.42791
# INFO:tensorflow:loss = 0.30832434, accuracy = 0.875 (10.605 sec)
# INFO:tensorflow:loss = 0.30832434, step = 6901 (10.605 sec)
# INFO:tensorflow:global_step/sec: 9.42953
# INFO:tensorflow:loss = 0.28751114, accuracy = 0.9375 (10.605 sec)
# INFO:tensorflow:loss = 0.28751114, step = 7001 (10.605 sec)
# INFO:tensorflow:global_step/sec: 9.43341
# INFO:tensorflow:loss = 0.2000049, accuracy = 0.90625 (10.601 sec)
# INFO:tensorflow:loss = 0.2000049, step = 7101 (10.601 sec)
# INFO:tensorflow:global_step/sec: 9.43002
# INFO:tensorflow:loss = 0.03274128, accuracy = 1.0 (10.604 sec)
# INFO:tensorflow:loss = 0.03274128, step = 7201 (10.605 sec)
# INFO:tensorflow:global_step/sec: 9.43025
# INFO:tensorflow:loss = 0.46588835, accuracy = 0.9375 (10.604 sec)
# INFO:tensorflow:loss = 0.46588835, step = 7301 (10.604 sec)
# INFO:tensorflow:global_step/sec: 9.43071
# INFO:tensorflow:loss = 0.020964764, accuracy = 1.0 (10.604 sec)
# INFO:tensorflow:loss = 0.020964764, step = 7401 (10.604 sec)
# INFO:tensorflow:global_step/sec: 9.42937
# INFO:tensorflow:loss = 0.18409178, accuracy = 0.90625 (10.605 sec)
# INFO:tensorflow:loss = 0.18409178, step = 7501 (10.605 sec)
# INFO:tensorflow:global_step/sec: 9.43175
# INFO:tensorflow:loss = 0.13758221, accuracy = 0.96875 (10.603 sec)
# INFO:tensorflow:loss = 0.13758221, step = 7601 (10.603 sec)
# INFO:tensorflow:global_step/sec: 9.42909
# INFO:tensorflow:loss = 0.031380493, accuracy = 1.0 (10.605 sec)
# INFO:tensorflow:loss = 0.031380493, step = 7701 (10.605 sec)
# INFO:tensorflow:global_step/sec: 9.42831
# INFO:tensorflow:loss = 0.25344628, accuracy = 0.90625 (10.608 sec)
# INFO:tensorflow:loss = 0.25344628, step = 7801 (10.608 sec)
# INFO:tensorflow:global_step/sec: 9.42014
# INFO:tensorflow:loss = 0.15991455, accuracy = 0.9375 (10.614 sec)
# INFO:tensorflow:loss = 0.15991455, step = 7901 (10.614 sec)
# INFO:tensorflow:global_step/sec: 9.42919
# INFO:tensorflow:loss = 0.06113355, accuracy = 1.0 (10.605 sec)
# INFO:tensorflow:loss = 0.06113355, step = 8001 (10.605 sec)
# INFO:tensorflow:global_step/sec: 9.42964
# INFO:tensorflow:loss = 0.10649554, accuracy = 0.96875 (10.605 sec)
# INFO:tensorflow:loss = 0.10649554, step = 8101 (10.605 sec)
# INFO:tensorflow:global_step/sec: 9.42926
# INFO:tensorflow:loss = 0.20498618, accuracy = 0.9375 (10.605 sec)
# INFO:tensorflow:loss = 0.20498618, step = 8201 (10.606 sec)
# INFO:tensorflow:global_step/sec: 9.42962
# INFO:tensorflow:loss = 0.1099097, accuracy = 0.96875 (10.605 sec)
# INFO:tensorflow:loss = 0.1099097, step = 8301 (10.605 sec)
# INFO:tensorflow:global_step/sec: 9.42907
# INFO:tensorflow:loss = 0.22902277, accuracy = 0.875 (10.605 sec)
# INFO:tensorflow:loss = 0.22902277, step = 8401 (10.605 sec)
# INFO:tensorflow:global_step/sec: 9.43002
# INFO:tensorflow:loss = 0.050783884, accuracy = 1.0 (10.604 sec)
# INFO:tensorflow:loss = 0.050783884, step = 8501 (10.604 sec)
# INFO:tensorflow:global_step/sec: 9.43132
# INFO:tensorflow:loss = 0.103445634, accuracy = 0.96875 (10.603 sec)
# INFO:tensorflow:loss = 0.103445634, step = 8601 (10.603 sec)
# INFO:tensorflow:global_step/sec: 9.42801
# INFO:tensorflow:loss = 0.027535712, accuracy = 1.0 (10.607 sec)
# INFO:tensorflow:loss = 0.027535712, step = 8701 (10.607 sec)
# INFO:tensorflow:global_step/sec: 9.42927
# INFO:tensorflow:loss = 0.18695328, accuracy = 0.875 (10.605 sec)
# INFO:tensorflow:loss = 0.18695328, step = 8801 (10.605 sec)
# INFO:tensorflow:global_step/sec: 9.43057
# INFO:tensorflow:loss = 0.3184856, accuracy = 0.875 (10.604 sec)
# INFO:tensorflow:loss = 0.3184856, step = 8901 (10.604 sec)
# INFO:tensorflow:global_step/sec: 9.43105
# INFO:tensorflow:loss = 0.15813008, accuracy = 0.96875 (10.603 sec)
# INFO:tensorflow:loss = 0.15813008, step = 9001 (10.603 sec)
# INFO:tensorflow:global_step/sec: 9.42934
# INFO:tensorflow:loss = 0.017969368, accuracy = 1.0 (10.605 sec)
# INFO:tensorflow:loss = 0.017969368, step = 9101 (10.605 sec)
# INFO:tensorflow:global_step/sec: 9.42049
# INFO:tensorflow:loss = 0.015275309, accuracy = 1.0 (10.615 sec)
# INFO:tensorflow:loss = 0.015275309, step = 9201 (10.615 sec)
# INFO:tensorflow:global_step/sec: 9.4286
# INFO:tensorflow:loss = 0.1081614, accuracy = 0.96875 (10.606 sec)
# INFO:tensorflow:loss = 0.1081614, step = 9301 (10.606 sec)
# INFO:tensorflow:global_step/sec: 9.41742
# INFO:tensorflow:loss = 0.12891431, accuracy = 0.9375 (10.619 sec)
# INFO:tensorflow:loss = 0.12891431, step = 9401 (10.619 sec)
# INFO:tensorflow:global_step/sec: 9.42919
# INFO:tensorflow:loss = 0.17884442, accuracy = 0.9375 (10.605 sec)
# INFO:tensorflow:loss = 0.17884442, step = 9501 (10.605 sec)
# INFO:tensorflow:global_step/sec: 9.42899
# INFO:tensorflow:loss = 0.07327816, accuracy = 0.96875 (10.606 sec)
# INFO:tensorflow:loss = 0.07327816, step = 9601 (10.606 sec)
# INFO:tensorflow:global_step/sec: 9.42546
# INFO:tensorflow:loss = 0.015514433, accuracy = 1.0 (10.610 sec)
# INFO:tensorflow:loss = 0.015514433, step = 9701 (10.609 sec)
# INFO:tensorflow:global_step/sec: 9.42865
# INFO:tensorflow:loss = 0.08425382, accuracy = 0.96875 (10.606 sec)
# INFO:tensorflow:loss = 0.08425382, step = 9801 (10.606 sec)
# INFO:tensorflow:global_step/sec: 9.4307
# INFO:tensorflow:loss = 0.100519076, accuracy = 0.96875 (10.604 sec)
# INFO:tensorflow:loss = 0.100519076, step = 9901 (10.604 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into saved_models/estimator_api/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.13329513.
# INFO:tensorflow:Starting evaluation at 2018-03-27-14:07:45
# INFO:tensorflow:Restoring parameters from saved_models/estimator_api/model.ckpt-10000
# INFO:tensorflow:Finished evaluation at 2018-03-27-14:07:47
# INFO:tensorflow:Saving dict for global step 10000: accuracy = 0.8457539, global_step = 10000, loss = 2.8988304
# {'accuracy': 0.8457539, 'loss': 2.8988304, 'global_step': 10000}
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2918: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
tf.reset_default_graph()
